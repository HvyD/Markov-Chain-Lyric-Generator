# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = open('data/all_artist_lyrics.txt')
Lyrics = f.read()
Lyrics = Lyrics.split()
df = pd.DataFrame(Lyrics)

# %%
df
# Out:
#               0
# 0            So
# 1        close,
# 2            no
# 3        matter
# 4           how
# 5           far
# 6      Couldn't
# 7            be
# 8          much
# 9          more
# 10         from
# 11          the
# 12        heart
# 13      Forever
# 14        trust
# 15           in
# 16          who
# 17           we
# 18          are
# 19          And
# 20      nothing
# 21         else
# 22      matters
# 23        Never
# 24       opened
# 25       myself
# 26         this
# 27          way
# 28         Life
# 29           is
# ...         ...
# 19590    doin',
# 19591       now
# 19592        Oh
# 19593     yeah,
# 19594       you
# 19595    really
# 19596       got
# 19597        me
# 19598       now
# 19599       You
# 19600       got
# 19601        me
# 19602        so
# 19603         I
# 19604     can't
# 19605     sleep
# 19606        at
# 19607     night
# 19608       You
# 19609    Really
# 19610       Got
# 19611        Me
# 19612       You
# 19613    Really
# 19614       Got
# 19615        Me
# 19616       You
# 19617    Really
# 19618       Got
# 19619        Me
#
# [19620 rows x 1 columns]

# %%
wordcloud = WordCloud(max_font_size=42).generate(str(df))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
